# %%
import numpy as np, matplotlib.pyplot as plt
from matplotlib.ticker import NullLocator, LinearLocator, MultipleLocator, IndexLocator, FixedLocator, LogLocator, MaxNLocator, NullFormatter, FormatStrFormatter, FuncFormatter, ScalarFormatter, FixedFormatter
from matplotlib.lines import Line2D
from matplotlib.patches import *
from PIL import Image
from mpl_toolkits.mplot3d import Axes3D
import time
from matplotlib.animation import FuncAnimation, ArtistAnimation

# %%
x = np.array([4, 5, 6, 7, 8])  # Если мы задаем множество значений по ox и передаем их вместе с множеством значений
# по oy в plot, то график будет строить по заданным абсциссам, иначе - по 0, 1, 2...
y = np.array([1, 2, -6, 0, 4])
plt.plot(x, y)
plt.show()

# Построим квадрат:

x = np.array([1, 1, 4, 4, 1])
y = np.array([4, 1, 1, 4, 4])
plt.plot(x, y)
plt.show()

# Построим y = sqrt(x):

y = np.arange(0, 5, 1)  # [0, 1, 2, 3, 4, 5]
x = np.array([a * a for a in y])  # [0, 1, 4, 9, 16, 25]
plt.plot(x, y)
plt.show()

# %%
# Также добавим второй график, который будет отображаться вместе с первым при обоюдной передаче в plot:

y2 = range(5)
x2 = [i + 1 for i in y2]
plt.plot(x, y, x2, y2)  # Либо можно написать два plot: plt.plot(x, y) и plt.plot(x2, y2)

# И к этому графику добавим сетку:

plt.grid()
plt.show()

# Также мы можем изменять стиль линий графиков посредством передачи в plot третьего параметра, они могут быть такими:
# '-' - Непрерывная линия(по умолчанию), '--' -  Штрихованная линия, '-.' - Штрихпунктрирная линия, ':' - Пунктирная линия, 'None' или ' ' - Без рисования линии
# Ну и можно менять цвета графиков, указывая их после стиля линии: {'b', 'g', 'r', 'c', 'm', 'y', 'k', 'w'}: b - blue, g - green, r - red, c - cyan b т.д.
# line1 = plt.plot(x, y, '-.w')
# line2 = plt.plot(x2, y2, 'g')
# print(line1, line2)  # Мы создали графики через line1 и line2 чтобы посмотреть, какими обьектами они являются, также мы можем ими управлять:
# Оставим неизменной line2 для сравнения, а над первой примерним всевозможные основные изменения с подписями:
# plt.setp(line1, ls = '--', c = 'r', lw = 4, marker = 'o', mfc = 'b', alpha = 0.6, mec = 'b', mew = 1, ms = 8, dash_capstyle = 'butt', dash_joinstyle = 'miter', solid_capstyle = 'butt', solid_joinstyle = 'miter', visible = True)
# linestyle или ls- стиль линии
# color или c - цвет линии
# linewidth или lw- ширина линий
# marker - стиль точек
# markerfacecolor или mfc - цвет заливки точек
# markeredgecolor или mec - цвет границы точек
# markeredgewidth или mew - толщина границы точек
# markersize или ms - размер точек
# alpha - прозрачность
# dash_capstyle - стиль штриховых конечных точек  'butt'/'round'/'projecting'
# dash_joinstyle - стиль штриховых соединительных точек   'miter'/'round'/'bevel'
# solid_capstyle - стиль конечных точек непрерывной линии   'butt'/'round'/'projecting'
# solid_joinstyle - стиль соединительных точек непрерывной линии  'miter'/'round'/'bevel'
# visible - показать/скрыть график - true/false

# %%
# Заливка областей графика
# fill_between(x, y1, y2 = 0, where = None, interpolate = False, step = None, *, data = None, **kwargs)
# x, y1 - массивы значений координат x и функции y1
# y2 - массив(или число) для второй кривой, до которой производится заливка
# where - массив булевых элементов, который определяет области для заливки

x = np.arange(-2 * np.pi, 2 * np.pi, 0.1)
y = np.cos(x)
plt.plot(x, y)
plt.fill_between(x, y, where = (y > 0), color = 'r', alpha = 0.5)
plt.fill_between(x, y, where = (y < 0), color = 'g', alpha = 0.5)
plt.grid()
plt.show()

# %%
# Отображение нескольких координатных осей
# subplot(mrows, ncols, index)
ax1 = plt.subplot(2, 3, 1)
plt.plot(np.random.random(10))
# plt.grid()
ax2 = plt.subplot(2, 3, 2)
plt.plot(np.random.random(10))
# plt.grid()
ax3 = plt.subplot(2, 3, 3)
plt.plot(np.random.random(10))
ax4 = plt.subplot(2, 1, 2)
plt.plot(np.random.random(10))
# plt.grid()
ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()
plt.show()

# %%
fig = plt.figure(figsize = (7, 4))  # создадим вторую фигуру
# plt.plot(np.arange(0, 5, 0.2))  # метод 1

ax1 = fig.add_axes([0.0, 0, 1.0, 1.0])  # метод 2
ax1.plot(np.arange(0, 5, 0.2))

# ax1 = fig.add_subplot(1, 3, 1)  # метод 3
# ax1.plot(np.arange(0, 5, 0.2))

# %%
f, ax = plt.subplots(2, 2)
f.set_size_inches(7, 4)   # размер 7*4 дюймов
f.set_facecolor('#eee')   # цвет фона - светло-серый
ax[0, 0].plot(np.arange(0, 5, 0.2))
ax[0, 0].grid()
ax[0, 1].plot(np.arange(5, 0, -0.2))
ax[0, 1].grid()
plt.show()

# %%
# Граничные значения у координатных осей
# ax.set(xlim = (xmin, xmax), ylim = (ymin, ymax))
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
ax.plot(np.arange(1, 5, 0.25))
ax.set(xlim = (-5, 30), ylim = (-1, 6))
ax.grid()
# Применим разные локаторы:
ax.xaxis.set_major_locator(NullLocator())  # Убирает сетку по оси ox

# %%
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
ax.plot(np.arange(1, 5, 0.25))
ax.set(xlim = (-5, 30), ylim = (-1, 6))
ax.grid()

ax.yaxis.set_major_locator(LinearLocator(5))  # если на оси нужно отметить фиксированное количество рисок

# %%
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
ax.plot(np.arange(1, 5, 0.25))
ax.set(xlim = (-5, 30), ylim = (-1, 6))
ax.grid()

ax.xaxis.set_major_locator(MultipleLocator(base = 1))  # если надо расставить риски через определенные равные интервалы

# %%
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
ax.plot(np.arange(1, 5, 0.25))
ax.set(xlim = (-5, 30), ylim = (-1, 6))
ax.grid()

ax.yaxis.set_major_locator(IndexLocator(base = 0.5, offset = 0))  # то же самое, что и MultipleLocator, 
ax.xaxis.set_major_locator(IndexLocator(base = 0.5, offset = 0))  # но отсчитывает риски от наименьшего значения, а не от нуля

# %%
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
ax.plot(np.arange(1, 5, 0.25))
ax.set(xlim = (-5, 30), ylim = (-1, 6))
ax.grid()

ax.yaxis.set_major_locator(FixedLocator([0, 1, 3, 4, 5]))  # устанавливает риски только в тех значениях, которые мы ему передаем

# %%
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
ax.plot(np.arange(1, 5, 0.25))
ax.set(xlim = (-5, 30), ylim = (-1, 6))
ax.grid()

ax.xaxis.set_major_locator(LogLocator(base = 2))  # делает шаг рисок логарифмическим

# %%
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
ax.plot(np.arange(1, 5, 0.25))
ax.set(xlim = (-5, 30), ylim = (-1, 6))
ax.grid()

ax.xaxis.set_major_locator(MaxNLocator(5))  # устанавливает ограничение по количеству рисок на оси, 
# но оптимизирует этот процесс сам, из-за чего рисок вполне может оказаться меньше

# %%
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
ax.plot(np.arange(1, 5, 0.25))
ax.set(xlim = (-5, 30), ylim = (-1, 6))
ax.grid()
ax.minorticks_on()  # добавим маленькие риски
ax.grid(which = 'major', lw = 2)
ax.grid(which = 'minor')
ax.xaxis.set_minor_locator(NullLocator()) # и отключим их по оси ox
plt.show()

# %%
# Формат отображения меток у координатных осей
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
x = np.arange(-np.pi / 2, np.pi / 2, 0.1)
ax.plot(x, np.sin(x) * 1e5)
plt.grid()

# ax.set_xticklabels(labels = [-1, 0, 0.5, 1])
# ax.set_yticklabels(labels = [-1, 0, 0.5, 1])

ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())

# %%
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
x = np.arange(-np.pi / 2, np.pi / 2, 0.1)
ax.plot(x, np.sin(x) * 1e5)
plt.grid()

ax.yaxis.set_major_formatter(FormatStrFormatter('y = %2f'))

# %%
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
x = np.arange(-np.pi / 2, np.pi / 2, 0.1)
ax.plot(x, np.sin(x) * 1e5)
plt.grid()

def format_oy(x, pos):
    return f'[{x}]' if x < 0 else f'({x})'
ax.xaxis.set_major_formatter(FuncFormatter(format_oy))

# %%
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
x = np.arange(-np.pi / 2, np.pi / 2, 0.1)
ax.plot(x, np.sin(x) * 1e5)
plt.grid()

sf = ScalarFormatter()
sf.set_powerlimits((-4, 4))
ax.yaxis.set_major_formatter(sf)

# %%
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
x = np.arange(-np.pi / 2, np.pi / 2, 0.1)
ax.plot(x, np.sin(x) * 1e5)
plt.grid()

ax.xaxis.set_major_formatter(FixedFormatter([-3, -2, -1, 0, 1, 2, 3]))  # Лучше использовать с FixedLocator
# Out:
# /var/folders/l9/88y_46d53y3cy1jh1h6qdg0c0000gn/T/ipykernel_35619/4015428653.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.xaxis.set_major_formatter(FixedFormatter([-3, -2, -1, 0, 1, 2, 3]))  # Лучше использовать с FixedLocator

# %%
# Логарифмический масштаб координатных осей
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()

x = np.arange(-10 * np.pi, 10 * np.pi, 0.1)
# ax.semilogy(x, np.sinc(x) * np.exp(-np.abs(x / 10)))
ax.plot(x, np.sinc(x) * np.exp(-np.abs(x / 10)))
ax.set_yscale('log', base = 10, subs = [2, 9])
ax.set_xscale('symlog')
# ax.loglog(x, np.sinc(x) * np.exp(-np.abs(x / 10)))  # если хотим логарифмический масштаб по обеим осям
# параметры: 'linear'(по умолчанию) - линейный масштаб, 'log' - логарифмический масштаб, 'symlog' - вблизи начала координат(можно выбирать грань) линейный масштаб, затем - логарифмический
ax.grid()
plt.show()

# %%
# Размещение текстовых элементов на графике
y = np.arange(0, 5, 1)
x = np.array([a * a for a in y])
y2 = [0, 2, 3, 4, 5, 7]
x2 = [i + 1 for i in y2]
lines = plt.plot(x, y, x2, y2)
plt.minorticks_on()
plt.grid(which = 'major', color = '#444', lw = 1)
plt.grid(which = 'minor', color = '#aaa', ls = ':')
plt.show()

# %%
# Создание надписей и подписей
# У каждой оси(объекта Axes) можно определять следующие текстовые элементы:
# title - заголовок для осей
# xlabel, ylabel - подписи для каждой из осей
# text - произвольная текстовая информация в области осей
# annnotate - аннотация - текст с указателем
# Также у окна в целом можно задавать такие текстовые элементы:
# subtitle - заголовок для фигуры(окна)
# figtext - размещение произвольной текстовой информации в области окна
fig = plt.figure(figsize = (7, 4))
fig.set(facecolor = '#eee')
ax = fig.add_subplot()
plt.figtext(0.05, 0.6, 'Текст в области окна')
fig.suptitle('Заголовок окна')
ax.set_xlabel('Ox')
ax.set_ylabel('Oy')
ax.text(0.05, 0.6, 'Произвольный текст в координатных осях')
ax.annotate('Аннотация', xy = (0.2, 0.4), xytext = (0.6, 0.7), arrowprops = {'facecolor': 'gray', 'shrink': 0.1})
# alpha - степень прозврачности
# backgroundcolor - цвет фона
# color - цвет текста
# fontfamily family - тип шрифта
# fontsize size - размер шрифта
# fontstyle style - стиль шрифта - 'normal'/'italic'/'oblique'
# fontweight weight - степень утолщения, число от 0 до 1000 или константы: 'ultralight'/'light'/'normal'/'regular'/'book'/'medium'/'roman'/'semibold'/'demibold'/'demi'/'bold'/'heavy'/'extrabold'/'black'
# horizontalalignment ha - выравнивание по горизонтали - 'center'/'right'/'left'
# label - текст заголовка
# position - координаты текста (x, y)
# rotation - поворот текста - число от 0 до 1 или 'vertical'/'horizontal'
# verticalalignment va - выравнивание по вертикали - 'center'/'top'/'bottom'/'baseline'/'center_baseline'
# Out:
# Text(0.6, 0.7, 'Аннотация')

# %%
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
line1, = ax.plot(np.arange(0, 5, 0.25), '--o', label = 'line1')
line2, = ax.plot(np.arange(0, 10, 0.5), ':s', label = 'line2')
# ax.legend((line2, line1), ['Линия 2', 'Линия 1'], bbox_to_anchor = (0.5, 0.7))
ax.legend((line2, line1), [r'$f(x) = a \cdot b + c$', r'$ f(x) = k \cdot x + b$'], facecolor = '#aaa', framealpha = 0.5)
plt.show()

# %%
x = np.arange(-2 * np.pi, 2 * np.pi, 0.1)
cos = Line2D(x, np.cos(x))
rect = Rectangle((0, 0), 2.5, 0.5, facecolor = 'g')
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
ax.add_patch(rect)  # добавим прямоугольник
ax.add_line(cos)  # добавим косинусоиду
ax.set(xlim = (-2 * np.pi, 2 * np.pi), ylim = (-1, 1))
plt.show()
# Из других фигур подмодуля patches есть такие:
# Arc - Для рисования дуг
# Arrow - Для рисования стрелок
# Circle - Для рисования окружностей
# CirclePolygon - Для рисования равносторонних многоугольников
# Ellipse - Для рисования эллипсов
# FancyBboxPatch - Для рисования прямоугольников с разными типами границ(с закругленными углами, в виде стрелок и т.д.)
# PathPatch - Для рисования линий или замкнутых областей
# Polygon - Для рисования многоугольников
# Rectangle - Для рисования прямоугольников
# Wedge - Для рисования "клина" - сегмента окружности

# %%
# Ступенчатый график
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
x = np.arange(0, 10)
ax.step(x, x, '-go', x, np.cos(x), '--x', where = 'post')
ax.grid()
plt.show()

# %%
# Стековый график
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
x = np.arange(-2, 2, 0.1)
y1 = np.array([-y ** 2 for y in x]) + 8
y2 = np.array([-y ** 2 for y in x]) + 8
y3 = np.array([-y ** 2 for y in x]) + 8
ax.stackplot(x, y1, y2, y3)
ax.grid()
plt.show()

# %%
# Stem - график
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
x = np.arange(-2 * np.pi, 2 * np.pi, 0.2)
ax.set(xlim = (-2 * np.pi, 2 * np.pi), ylim = (-1.2, 1.2))
ax.grid()
ax.stem(x, np.cos(x), '--r', '^g', bottom = 0.5)
plt.show()
# Out:
# /var/folders/l9/88y_46d53y3cy1jh1h6qdg0c0000gn/T/ipykernel_35619/3287589554.py:7: MatplotlibDeprecationWarning: Passing the markerfmt parameter positionally is deprecated since Matplotlib 3.5; the parameter will become keyword-only two minor releases later.
#   ax.stem(x, np.cos(x), '--r', '^g', bottom = 0.5)

# %%
# Точечный график
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
x = np.random.normal(0, 2, 500)
y = np.random.normal(0, 2, 500)
ax.scatter(x, y, s = 50, c = 'g', lw = 1, marker = 's', edgecolors = 'r')
ax.grid()
plt.show()

# %%
# Гистограмма
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
y = np.random.normal(0, 2, 500)
ax.hist(y, 50)
ax.grid()
plt.show()

# %%
# Столбчатая диаграмма
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
x = [f'H{i + 1}' for i in range(10)]
y = np.random.randint(1, 5, len(x))
ax.bar(x, y)
ax.grid()
plt.show()

# %%
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
y = np.random.normal(0, 2, 500)
x = np.linspace(np.min(y), np.max(y), 10)
bars = [len(y[np.bitwise_and(y >= x[i], y < x[i + 1])]) for i in range(len(x) - 1)]
ax.bar(range(len(x) - 1), bars)
ax.grid()
plt.show()

# %%
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
x = [f'H{i + 1}' for i in range(10)]
y = np.random.randint(-20, 20, len(x))
ax.bar(x, y, width = 0.5, linewidth = 2, edgecolor = 'r', yerr = 2, bottom = 10)
ax.grid()
plt.show()

# %%
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
x = np.arange(10)
y1 = np.random.randint(3, 20, len(x))
y2 = np.random.randint(3, 20, len(x))
w = 0.3
ax.bar(x - w/2, y1, width = w)
ax.bar(x + w/2, y2, width = w)
ax.grid()
plt.show()

# %%
# Круговые диаграммы
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
vals = [10, 40, 23, 30, 7]
labels = ['Toyota', 'BMW', 'Lexus', 'Audi', 'Lada']
exp = (0.1, 0.2, 0, 0, 0)
ax.pie(vals, labels = labels, autopct = '%.2f', explode = exp, shadow = True)
ax.grid()
plt.show()

# %%
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
vals = [10, 40, 23, 30, 7]
labels = ['Toyota', 'BMW', 'Lexus', 'Audi', 'Lada']
ax.pie(vals, labels = labels, autopct = '%.2f', wedgeprops = dict(width = 0.5) , shadow = True)
ax.grid()
plt.show()

# %%
# Показ изображений и цветовых сеток
img = Image.open('/Users/dadaya/Desktop/fallout.jpg')
fig = plt.figure(figsize = (7, 4))
ax = fig.add_subplot()
ax.imshow(img)
plt.show()

# %%
data = np.random.randint(0, 255, (100, 100))
plt.imshow(data, cmap = 'plasma')
plt.show()

# %%
img = Image.open('/Users/dadaya/Desktop/fallout.jpg')
plt.imshow(img, origin = 'lower', cmap = 'gray', aspect = 'equal', alpha = 0.7)
plt.colorbar()
plt.show()

# %%
data = np.random.randint(0, 255, (10, 10))
b = plt.pcolormesh(data, edgecolors = 'black', cmap = 'plasma')
plt.colorbar(b)
plt.show()

# %%
# Трехмерные графики
fig = plt.figure(figsize = (7, 4))
ax_3d = fig.add_subplot(projection = '3d')
plt.show()
# plot() - линейный 2D график в трех измерениях
# step() - ступенчаный 2D график в трех измерениях
# scatter() - точечный 3D график
# plot_wireframe() - построение каркасной поверхности в 3D
# plot_surface() - построение непрерывной 3D поверхности

# %%
fig = plt.figure(figsize = (7, 4))
ax_3d = fig.add_subplot(projection = '3d')
x = np.linspace(0, 10, 50)
z = np.cos(x)
ax_3d.plot(x, x, z)
ax_3d.set_xlabel('x')
ax_3d.set_ylabel('y')
ax_3d.set_zlabel('z')
plt.show()

# %%
# Построим график функции f(x, y) = sin(x) * sin(y) / x * y
fig = plt.figure(figsize = (7, 4))
ax_3d = fig.add_subplot(projection = '3d')
x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
xgrid, ygrid = np.meshgrid(x, y)
zgrid = np.sin(xgrid) * np.sin(ygrid) / (xgrid * ygrid)
ax_3d.plot_wireframe(xgrid, ygrid, zgrid, rstride = 5, cstride = 5) # строит каркасную стеку
# ax_3d.plot_surface(xgrid, ygrid, zgrid) # строит поверхность
# ax_3d.scatter(xgrid, ygrid, zgrid, s = 1, c = 'g') # строит множество точек
plt.show()

# %%
fig, ax = plt.subplots(1, 2)
x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
xgrid, ygrid = np.meshgrid(x, y)
zgrid = np.sin(xgrid) * np.sin(ygrid) / (xgrid * ygrid)
c1 = ax[0].contour(xgrid, ygrid, zgrid, cmap = 'plasma')
ax[1].contourf(xgrid, ygrid, zgrid)
c1.clabel(colors = 'k', fmt = '%.2f')
plt.show()

# %%
fig, ax = plt.subplots(1, 2)
x = np.random.rand(100) * 4 * np.pi - 2*np.pi
y = np.random.rand(100) * 4 * np.pi - 2*np.pi
z = np.sin(x) * np.sin(y) / (1 + np.abs(x * y))
c1 = ax[0].tricontour(x, y, z, cmap = 'plasma')
ax[1].tricontourf(x, y, z)
c1.clabel(colors = 'k', fmt = '%.2f')
plt.show()

# %%
# Анимации графиков
x = np.arange(-2 * np.pi, 2 * np.pi, 0.1)
plt.ion() # Включили анимационный режим отображения графиков
for delay in np.arange(0, np.pi, 0.1):
    y = np.cos(x + delay)
    plt.clf()
    plt.plot(x, y)
    plt.draw()
    plt.gcf().canvas.flush_events()
    time.sleep(0.02)
plt.ioff
plt.show()

# %%
plt.ion()
fig, ax = plt.subplots()
x = np.arange(-2 * np.pi, 2 * np.pi, 0.1)
y = np.cos(x)
line, = ax.plot(x, y)
for delay in np.arange(0, np.pi, 0.1):
    y = np.cos(x + delay)
    line.set_ydata(y)
    plt.draw()
    plt.gcf().canvas.flush_events()
    time.sleep(0.02)
plt.ioff()
plt.show()

# %%
fig, ax = plt.subplots()
x = np.arange(-2 * np.pi, 2 * np.pi, 0.1)
y = np.cos(x)
line, = ax.plot(x, y)
def update_cos(frame, lene, x):
    # frame - параметр, который меняется от кадра к кадру
    # в данном случае - это начальная фаза (угол)
    # line - ссылка на объект Line2D
    line.set_ydata( np.cos(x+frame) )
    return [line]
phasa = np.arange(0, 4*np.pi, 0.1)
animation = FuncAnimation(
    fig,                # фигура, где отображается анимация
    func=update_cos,    # функция обновления текущего кадра
    frames=phasa,       # параметр, меняющийся от кадра к кадру
    fargs=(line, x),    # дополнительные параметры для функции update_cos
    interval=30,       # задержка между кадрами в мс
    blit=True,          # использовать ли двойную буферизацию
    repeat=True)       # зацикливать ли анимацию
plt.show()

# %%
fig = plt.figure(figsize = (10, 6))
ax_3d = fig.add_subplot(projection = '3d')
x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)
xgrid, ygrid = np.meshgrid(x, y)
phasa = np.arange(0, 2*np.pi, 0.1)
frames = []
for p in phasa:
    zgrid = np.sin(xgrid + p) * np.sin(ygrid) / (xgrid * ygrid)
    line = ax_3d.plot_surface(xgrid, ygrid, zgrid, color = 'b')
    frames.append([line])
animation = ArtistAnimation(
    fig,                # фигура, где отображается анимация
    frames,              # кадры
    interval=30,        # задержка между кадрами в мс
    blit=True,          # использовать ли двойную буферизацию
    repeat=True)       # зацикливать ли анимацию
plt.show()
